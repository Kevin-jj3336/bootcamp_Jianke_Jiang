# %%
import numpy as np

#Create an array and perform elementwise operations.
arr = np.array([1, 2, 3, 4, 5])
print("cube:", arr ** 3)
# Out:
# cube: [  1   8  27  64 125]

# %%
import time

#Compare loop vs vectorized execution.
# Vectorized operation
start = time.time()
result_vec = arr * 9999
end = time.time()
print(f"Vectorized: {end - start:.6f}s")

# Loop operation
start = time.time()
result_loop = [x * 9999 for x in arr]
end = time.time()
print(f"Loop: {end - start:.6f}s")
# Out:
# Vectorized: 0.000041s
# Loop: 0.000040s

# %%
import pandas as pd
#Load provided CSV (data/starter_data.csv) using pandas.
df = pd.read_csv('../data/starter_data.csv')

#Inspect with .info() and .head().

print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     float64
#  1   A           16 non-null     float64
#  2   B           16 non-null     float64
#  3   C           16 non-null     float64
#  4   Unnamed: 4  0 non-null      float64
#  5   Unnamed: 5  1 non-null      object
# dtypes: float64(5), object(1)
# memory usage: 1.1+ KB
# None
#    Unnamed: 0    A     B    C  Unnamed: 4 Unnamed: 5
# 0         0.0  5.0   0.0  9.0         NaN        NaN
# 1         1.0  3.0  20.0  3.0         NaN        NaN
# 2         2.0  1.0   1.2 -4.0         NaN        NaN
# 3         3.0  2.0   4.5  2.0         NaN        NaN
# 4         4.0  2.0   4.2  4.0         NaN        NaN

# %%
#Calculate .describe() for numeric columns.
numeric_summary = df.describe()
print(numeric_summary)


#Perform .groupby() aggregation by category.
grouped = df.groupby('A').sum()
print(grouped)
# Out:
#        Unnamed: 0         A         B          C  Unnamed: 4
# count   16.000000  16.00000  16.00000  16.000000         0.0
# mean     7.500000   2.50000   4.16875   6.562500         NaN
# std      4.760952   1.21106   6.54693   9.912744         NaN
# min      0.000000   1.00000  -1.00000  -4.000000         NaN
# 25%      3.750000   2.00000   0.00000   2.000000         NaN
# 50%      7.500000   2.00000   2.70000   3.500000         NaN
# 75%     11.250000   3.00000   4.50000   9.000000         NaN
# max     15.000000   5.00000  20.00000  25.000000         NaN
#      Unnamed: 0     B     C  Unnamed: 4 Unnamed: 5
# A
# 1.0        20.0   3.6 -12.0         0.0          0
# 2.0        49.0  26.1  18.0         0.0          0
# 3.0        41.0  37.0  81.0         0.0          0
# 5.0        10.0   0.0  18.0         0.0          0

# %%
#Save summary stats to data/processed/summary.csv or .json.
numeric_summary.to_csv('../data/processed/summary.csv')
grouped.to_csv('../data/processed/grouped_summary.csv')

# %%
#a custom utility function
def is_std_bigger_than_ten(dataframe, threshold):
    stds = df.std(numeric_only=True)
    large_std = {col: val for col, val in stds.items() if val > threshold}
    return large_std


stats = is_std_bigger_than_ten(df, 10)
print(stats)
# Out:
# {'overall': {'Unnamed: 0': {'count': 16.0, 'mean': 7.5, 'std': 4.760952285695233, 'min': 0.0, '25%': 3.75, '50%': 7.5, '75%': 11.25, 'max': 15.0}, 'A': {'count': 16.0, 'mean': 2.5, 'std': 1.2110601416389966, 'min': 1.0, '25%': 2.0, '50%': 2.0, '75%': 3.0, 'max': 5.0}, 'B': {'count': 16.0, 'mean': 4.16875, 'std': 6.546929942092452, 'min': -1.0, '25%': 0.0, '50%': 2.7, '75%': 4.5, 'max': 20.0}, 'C': {'count': 16.0, 'mean': 6.5625, 'std': 9.912744322335769, 'min': -4.0, '25%': 2.0, '50%': 3.5, '75%': 9.0, 'max': 25.0}, 'Unnamed: 4': {'count': 0.0, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}}}
