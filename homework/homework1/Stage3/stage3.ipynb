# %% [markdown]
# Stage 3 HW

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print("cube:", arr ** 3)

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

import time

start = time.time()
result_vec = arr * 2 + 5
end = time.time()
print(f"Vectorized: {end - start:.6f}s")


start = time.time()
result_loop = [x * 2 + 5 for x in arr]
end = time.time()
print(f"Loop: {end - start:.6f}s")
# Out:
# Vectorized: 0.000033s
# Loop: 0.000026s
